# %%
import pandas as pd

csv = pd.read_csv("C:/Users/Allose/Notebook/cell_types_specimen_details.csv")

filtered = csv[csv['m__biophys_all_active']==1]
list_id = list(filtered['specimen__id'])
print(len(list_id))
# Out:
# 107

# %%
import requests

list_nm_id = []
for ids in list_id:
    specimen_id = ids
    url = 'http://celltypes.brain-map.org/api/v2/data/query.json?criteria=model::NeuronalModel,rma::criteria,[specimen_id$eq{}]&include=neuronal_model_template,neuronal_model_runs(well_known_files[well_known_file_type_id$eq478840678]),rma::options[order$eq%27neuronal_model_templates.name%27]'.format(specimen_id)
    json_data = requests.get(url).json()
    json_msg = json_data['msg']
    list_nm_id.append(json_msg[-1]['id'])

# %%
print(list_nm_id)
# Out:
# [501349504, 477876583, 478809991, 478513415, 480624414, 501349536, 485611914, 479694384, 477838913, 471086533, 515175253, 480630211, 484628276, 473871773, 480630344, 478513461, 501349563, 472455509, 489931686, 478513187, 485507735, 476637699, 478513407, 488083972, 479234670, 473863035, 480051220, 486909496, 485694403, 478045081, 482529696, 329321704, 471087975, 472912177, 473834758, 480631286, 479234441, 472450023, 478045202, 480633088, 485513184, 472421285, 478513398, 477878284, 477880244, 476637796, 479234506, 472352327, 478045226, 473862421, 482657528, 478513437, 501349486, 483106906, 472363762, 501349545, 479427369, 472299294, 473862496, 515175225, 477313251, 488462965, 472440759, 482934212, 480056382, 486509958, 472451419, 482524837, 486052412, 479427516, 477510985, 472300877, 478513441, 472447460, 501349572, 472306460, 485904766, 472306616, 476679102, 473465774, 483108201, 486508647, 485602029, 472304676, 478809612, 478045347, 491766131, 486558444, 476630516, 486144663, 4830663
# ...

# %%
print(list_id)
print(len(list_nm_id))
# Out:
# [485909730, 323865917, 480087928, 531520637, 314804042, 488679042, 527942865, 529807751, 476457450, 477127614, 528042185, 471085676, 471129934, 508282493, 571709783, 484742372, 571718621, 478793814, 508421103, 485468180, 530062215, 527891102, 476104386, 479721491, 313862167, 480114344, 488680211, 488697163, 525018757, 323540736, 485574721, 482644550, 318733871, 323452196, 476754635, 480640846, 482690728, 468120757, 370351753, 528038990, 473543792, 349621141, 386970660, 488420599, 329550137, 548494556, 490382353, 483111429, 488677994, 466245544, 466664172, 471789504, 531526539, 558211203, 324521027, 486111903, 569820026, 488674910, 321708130, 323834998, 480116737, 484564503, 481136138, 324466858, 488501071, 469753383, 483020137, 325941643, 473540161, 396608557, 486132712, 478396248, 479728896, 318808427, 479179020, 486146717, 486502127, 476616076, 485184849, 475585413, 480351780, 320207387, 486893033, 314822529, 324025371, 330080937, 314900022, 321906005, 508378649, 469610831, 4780583
# ...

# %%
for ids in list_id[100:150]:
    specimen_id = ids
    url = 'http://celltypes.brain-map.org/api/v2/data/query.json?criteria=model::NeuronalModel,rma::criteria,[specimen_id$eq{}]&include=neuronal_model_template,neuronal_model_runs(well_known_files[well_known_file_type_id$eq478840678]),rma::options[order$eq%27neuronal_model_templates.name%27]'.format(specimen_id)
    json_data = requests.get(url).json()
    json_msg = json_data['msg']
    list_nm_id.append(json_msg[-1]['id'])

# %%
print(list_nm_id)
print(len(list_nm_id))
# Out:
# [486509232, 480624051, 482583564, 626170592, 473863510, 489932597, 626170718, 626170661, 477876583, 478809991, 560692892, 478513415, 480624414, 626170801, 626170430, 485611914, 626170421, 479694384, 549384713, 485720587, 626170610, 626170727, 477838913, 482520370, 471086533, 483108490, 489932435, 491517388, 556384271, 480630211, 486052435, 484620556, 329322394, 480631187, 477878554, 485467083, 484628276, 473871773, 472442377, 561405645, 476637723, 480613522, 480630344, 488763268, 480630395, 626170511, 491625600, 485513255, 489932551, 471081668, 478513461, 472430904, 626170583, 626170502, 480632564, 486556811, 626170475, 489932183, 480631048, 472455509, 482655070, 485591776, 485476031, 473835796, 489931686, 478513187, 485507735, 473871592, 476637699, 478513407, 488083972, 479234670, 482525598, 473863035, 480051220, 486557284, 486909496, 478810017, 485694403, 478045081, 482529696, 329321704, 487245719, 471087975, 472434498, 472912177, 473862845, 473834758, 552636652, 480631286, 4792344
# ...

# %%
for ids in list_id[150:238]:
    specimen_id = ids
    url = 'http://celltypes.brain-map.org/api/v2/data/query.json?criteria=model::NeuronalModel,rma::criteria,[specimen_id$eq{}]&include=neuronal_model_template,neuronal_model_runs(well_known_files[well_known_file_type_id$eq478840678]),rma::options[order$eq%27neuronal_model_templates.name%27]'.format(specimen_id)
    json_data = requests.get(url).json()
    json_msg = json_data['msg']
    list_nm_id.append(json_msg[-1]['id'])

# %%
print(list_nm_id)
print(len(list_nm_id))
# Out:
# [486509232, 480624051, 482583564, 626170592, 473863510, 489932597, 626170718, 626170661, 477876583, 478809991, 560692892, 478513415, 480624414, 626170801, 626170430, 485611914, 626170421, 479694384, 549384713, 485720587, 626170610, 626170727, 477838913, 482520370, 471086533, 483108490, 489932435, 491517388, 556384271, 480630211, 486052435, 484620556, 329322394, 480631187, 477878554, 485467083, 484628276, 473871773, 472442377, 561405645, 476637723, 480613522, 480630344, 488763268, 480630395, 626170511, 491625600, 485513255, 489932551, 471081668, 478513461, 472430904, 626170583, 626170502, 480632564, 486556811, 626170475, 489932183, 480631048, 472455509, 482655070, 485591776, 485476031, 473835796, 489931686, 478513187, 485507735, 473871592, 476637699, 478513407, 488083972, 479234670, 482525598, 473863035, 480051220, 486557284, 486909496, 478810017, 485694403, 478045081, 482529696, 329321704, 487245719, 471087975, 472434498, 472912177, 473862845, 473834758, 552636652, 480631286, 4792344
# ...

# %%
from allensdk.core.cell_types_cache import CellTypesCache
from allensdk.api.queries.cell_types_api import CellTypesApi
import pandas as pd

# Initialize the cache and dget the metadata for cells, download if neccessary (to current directory)
ctc = CellTypesCache(manifest_file='cell_types/manifest.json')
cells = ctc.get_cells()

# Get the ephys features of all cells, download if neccessary
ephys_features = ctc.get_ephys_features()
ef_df = pd.DataFrame(ephys_features)

morph_features = ctc.get_morphology_features()
morph_df = pd.DataFrame(morph_features)

cells
# Out:
# C:\Users\Allose\Anaconda3\lib\site-packages\allensdk\api\cache.py:386: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   'reader': lambda f: pd.DataFrame.from_csv(f).to_dict('records')
# [{'reporter_status': None,
#   'cell_soma_location': [273.0, 354.0, 216.0],
#   'species': 'Homo Sapiens',
#   'id': 525011903,
#   'name': 'H16.03.003.01.14.02',
#   'structure_layer_name': '3',
#   'structure_area_id': 12113,
#   'structure_area_abbrev': 'FroL',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'intact',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 524848408,
#   'structure_hemisphere': 'right',
#   'normalized_depth': None},
#  {'reporter_status': 'positive',
#   'cell_soma_location': [8966.56330957526, 1429.52689052075, 8567.389672505],
# ...

# %%
from allensdk.api.queries.biophysical_api import \
    BiophysicalApi

bp = BiophysicalApi()

for neuronal_model_id in list_nm_id[0:4]:
    bp.cache_stimulus = False # change to False to not download the large stimulus NWB file
       # get this from the web site as above
    bp.cache_data(neuronal_model_id, working_directory='{}'.format(neuronal_model_id))
# Out:
# 2019-05-19 14:50:25,994 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/491392790
# 2019-05-19 14:50:27,620 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/496607259
# 2019-05-19 14:50:27,824 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337293
# 2019-05-19 14:50:28,014 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337054
# 2019-05-19 14:50:28,200 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337225
# 2019-05-19 14:50:28,772 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337019
# ...

# %%
for neuronal_model_id in list_nm_id[4:6]:
    bp.cache_stimulus = False # change to False to not download the large stimulus NWB file
       # get this from the web site as above
    bp.cache_data(neuronal_model_id, working_directory='{}'.format(neuronal_model_id))
# Out:
# 2019-05-19 14:51:20,104 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/491392790
# 2019-05-19 14:51:21,650 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/496607259
# 2019-05-19 14:51:22,336 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337293
# 2019-05-19 14:51:22,795 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337054
# 2019-05-19 14:51:23,374 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337225
# 2019-05-19 14:51:24,206 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337019
# ...

# %%
for neuronal_model_id in list_nm_id[6:7]:
    bp.cache_stimulus = False # change to False to not download the large stimulus NWB file
       # get this from the web site as above
    bp.cache_data(neuronal_model_id, working_directory='{}'.format(neuronal_model_id))
# Out:
# 2019-05-19 15:03:42,589 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/601947673
# 2019-05-19 15:03:44,710 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/601947676
# 2019-05-19 15:03:44,867 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337293
# 2019-05-19 15:03:45,142 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337054
# 2019-05-19 15:03:45,303 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337225
# 2019-05-19 15:03:45,537 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337019
# ...

# %%
for neuronal_model_id in list_nm_id[8:]:
    bp.cache_stimulus = False # change to False to not download the large stimulus NWB file
       # get this from the web site as above
    bp.cache_data(neuronal_model_id, working_directory='{}'.format(neuronal_model_id))
# Out:
# 2019-05-19 15:05:03,713 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/491253860
# 2019-05-19 15:05:05,440 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/496607180
# 2019-05-19 15:05:05,701 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337293
# 2019-05-19 15:05:05,876 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337054
# 2019-05-19 15:05:06,047 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337225
# 2019-05-19 15:05:07,404 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337019
# ...

# %%
for neuronal_model_id in list_nm_id[13:]:
    bp.cache_stimulus = False # change to False to not download the large stimulus NWB file
       # get this from the web site as above
    bp.cache_data(neuronal_model_id, working_directory='{}'.format(neuronal_model_id))
# Out:
# 2019-05-19 15:11:22,288 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/582653921
# 2019-05-19 15:11:25,269 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/582653929
# 2019-05-19 15:11:25,637 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337293
# 2019-05-19 15:11:25,921 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337054
# 2019-05-19 15:11:26,221 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337225
# 2019-05-19 15:11:26,464 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337019
# ...

# %%
for neuronal_model_id in list_nm_id[13:]:
    bp.cache_stimulus = False # change to False to not download the large stimulus NWB file
       # get this from the web site as above
    bp.cache_data(neuronal_model_id, working_directory='{}'.format(neuronal_model_id))
# Out:
# 2019-05-19 15:12:46,357 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/582653921
# 2019-05-19 15:13:01,835 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/582653929
# 2019-05-19 15:13:02,091 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337293
# 2019-05-19 15:13:02,356 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337054
# 2019-05-19 15:13:02,565 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337225
# 2019-05-19 15:13:02,793 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337019
# ...

# %%
for neuronal_model_id in list_nm_id[15:]:
    bp.cache_stimulus = False # change to False to not download the large stimulus NWB file
       # get this from the web site as above
    bp.cache_data(neuronal_model_id, working_directory='{}'.format(neuronal_model_id))
# Out:
# 2019-05-19 15:15:30,245 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/496079436
# 2019-05-19 15:15:34,352 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/496605067
# 2019-05-19 15:15:34,732 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337293
# 2019-05-19 15:15:35,153 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337054
# 2019-05-19 15:15:35,446 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337225
# 2019-05-19 15:15:35,793 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337019
# ...

# %%
for neuronal_model_id in list_nm_id[17:]:
    bp.cache_stimulus = False # change to False to not download the large stimulus NWB file
       # get this from the web site as above
    bp.cache_data(neuronal_model_id, working_directory='{}'.format(neuronal_model_id))
# Out:
# 2019-05-19 15:17:50,993 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/491119690
# 2019-05-19 15:17:51,675 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/496607559
# 2019-05-19 15:17:51,841 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337293
# 2019-05-19 15:17:55,107 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337054
# 2019-05-19 15:17:55,356 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337225
# 2019-05-19 15:17:55,509 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337019
# ...

# %%
for neuronal_model_id in list_nm_id[63:]:
    bp.cache_stimulus = False # change to False to not download the large stimulus NWB file
       # get this from the web site as above
    bp.cache_data(neuronal_model_id, working_directory='{}'.format(neuronal_model_id))
# Out:
# 2019-05-19 15:35:30,955 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/491458444
# 2019-05-19 15:35:32,206 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/496604541
# 2019-05-19 15:35:32,377 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337293
# 2019-05-19 15:35:32,538 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337054
# 2019-05-19 15:35:32,702 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337225
# 2019-05-19 15:35:32,850 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337019
# ...

# %%
from allensdk.api.queries.biophysical_api import \
    BiophysicalApi

bp = BiophysicalApi()

neuronal_model_id = 626170661
bp.cache_stimulus = False # change to False to not download the large stimulus NWB file
       # get this from the web site as above
bp.cache_data(neuronal_model_id, working_directory='{}'.format(neuronal_model_id))
# Out:
# 2019-05-21 12:11:11,008 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/667320244
# 2019-05-21 12:11:14,280 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/667320247
# 2019-05-21 12:11:14,464 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337293
# 2019-05-21 12:11:14,636 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337054
# 2019-05-21 12:11:14,809 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337225
# 2019-05-21 12:11:14,976 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337019
# ...

# %%
for neuronal_model_id in list_nm_id[206:]:
    bp.cache_stimulus = False # change to False to not download the large stimulus NWB file
       # get this from the web site as above
    bp.cache_data(neuronal_model_id, working_directory='{}'.format(neuronal_model_id))
# Out:
# 2019-05-20 10:27:40,079 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/491771277
# 2019-05-20 10:27:40,731 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/496606873
# 2019-05-20 10:27:40,932 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337293
# 2019-05-20 10:27:41,105 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337054
# 2019-05-20 10:27:41,286 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337225
# 2019-05-20 10:27:41,456 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337019
# ...

# %%
486512814

# %%
list_nm_id[205]
# Out:
# 515175279

# %%
for neuronal_model_id in list_nm_id[136:]:
    bp.cache_stimulus = False # change to False to not download the large stimulus NWB file
       # get this from the web site as above
    bp.cache_data(neuronal_model_id, working_directory='{}'.format(neuronal_model_id))
# Out:
# 2019-05-19 23:05:42,850 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/496085274
# 2019-05-19 23:05:43,633 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/496605635
# 2019-05-19 23:05:43,799 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337293
# 2019-05-19 23:05:43,958 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337054
# 2019-05-19 23:05:44,140 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337225
# 2019-05-19 23:05:44,305 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337019
# ...

# %%
from allensdk.core.cell_types_cache import CellTypesCache
from allensdk.api.queries.cell_types_api import CellTypesApi

ctc = CellTypesCache(manifest_file='cell_types/manifest.json')
datafile = ctc.get_ephys_data(490387590)

print(len(datafile))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-8b79da29bf51> in <module>
#       5 datafile = ctc.get_ephys_data(490387590)
#       6
# ----> 7 print(len(datafile))
#
# TypeError: object of type 'NwbDataSet' has no len()

# %%
nm_list = [486509232, 480624051, 482583564, 626170592, 473863510, 489932597, 626170718, 626170661, 477876583, 478809991, 560692892, 478513415, 480624414, 626170801, 626170430, 485611914, 626170421, 479694384, 549384713, 485720587, 626170610, 626170727, 477838913, 482520370, 471086533, 483108490, 489932435, 491517388, 556384271, 480630211, 486052435, 484620556, 329322394, 480631187, 477878554, 485467083, 484628276, 473871773, 472442377, 561405645, 476637723, 480613522, 480630344, 488763268, 480630395, 626170511, 491625600, 485513255, 489932551, 471081668, 478513461, 472430904, 626170583, 626170502, 480632564, 486556811, 626170475, 489932183, 480631048, 472455509, 482655070, 485591776, 485476031, 473835796, 489931686, 478513187, 485507735, 473871592, 476637699, 478513407, 488083972, 479234670, 482525598, 473863035, 480051220, 486557284, 486909496, 478810017, 485694403, 478045081, 482529696, 329321704, 487245719, 471087975, 472434498, 472912177, 473862845, 473834758, 552636652, 480631286, 479234441, 538907315, 478513445, 478513451, 488759006, 472450023, 478513443, 478045202, 473872986, 487245118, 480633088, 477876559, 480624126, 485513184, 472421285, 478513398, 477878284, 477880244, 476637796, 479234506, 488462820, 472352327, 626170646, 477839642, 478045226, 473862421, 480632594, 483156585, 482657528, 478513437, 483106906, 472363762, 487245869, 626170556, 556384280, 489932682, 626170619, 479427369, 626170574, 626170601, 472299294, 486508789, 473862496, 489932472, 477313251, 488462965, 486511108, 491623973, 486512814, 472440759, 482934212, 480056382, 489931963, 486509958, 479695152, 626170736, 472451419, 471085845, 626170670, 478048947, 482524837, 488462783, 486052412, 479427516, 479427443, 485510685, 477510985, 478047618, 538907329, 478043748, 480630857, 472300877, 478513441, 626170484, 472447460, 476637747, 538906694, 478047737, 486556714, 472306460, 478513459, 485904766, 549384722, 472306616, 476679102, 473465774, 479694359, 480631402, 560692910, 477839613, 485909152, 486556597, 626170439, 483108201, 486508647, 485602029, 496930338, 626170529, 626170565, 472304676, 473465456, 626170679, 626170520, 626170547, 472912107, 554338972, 479694721, 482657381, 626170538, 626170637, 478809612, 477840124, 478513396, 478045347, 486558444, 515175279, 476630516, 486144663, 486509010, 483066358, 480624251, 478513411, 543285979, 473863578, 487246046, 480633479, 478513224, 485510712, 485591806, 478047816, 626170628, 472306544, 486508702, 477510918, 480629276, 482525264, 485909125, 479234530, 488461970, 479694856, 480361288, 478047588, 485720616, 626170709, 486508758, 477494382, 483109057, 472299363]
list.sort()
print(list)
# Out:
# [329321704, 329322394, 471081668, 471085845, 471086533, 471087975, 472299294, 472299363, 472300877, 472304676, 472306460, 472306544, 472306616, 472352327, 472363762, 472421285, 472430904, 472434498, 472440759, 472442377, 472447460, 472450023, 472451419, 472455509, 472912107, 472912177, 473465456, 473465774, 473834758, 473835796, 473862421, 473862496, 473862845, 473863035, 473863510, 473863578, 473871592, 473871773, 473872986, 476630516, 476637699, 476637723, 476637747, 476637796, 476679102, 477313251, 477494382, 477510918, 477510985, 477838913, 477839613, 477839642, 477840124, 477876559, 477876583, 477878284, 477878554, 477880244, 478043748, 478045081, 478045202, 478045226, 478045347, 478047588, 478047618, 478047737, 478047816, 478048947, 478513187, 478513224, 478513396, 478513398, 478513407, 478513411, 478513415, 478513437, 478513441, 478513443, 478513445, 478513451, 478513459, 478513461, 478809612, 478809991, 478810017, 479234441, 479234506, 479234530, 479234670, 479427369, 4794274
# ...

# %%
import pandas as pd
pd.DataFrame()

# %%
from allensdk.core.dat_utilities import \
    DatUtilities
from allensdk.core.nwb_data_set import \
    NwbDataSet
import numpy as np
import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt

nwb_file = '491625600.nwb'
sweep_number = 52
dat_file = '491625600_%d.dat' % (sweep_number)

nwb = NwbDataSet(nwb_file)
sweep = nwb.get_sweep(sweep_number)

# read v and t as numpy arrays
v = sweep['response']
dt = 1.0e3 / sweep['sampling_rate']
num_samples = len(v)
t = np.arange(num_samples) * dt

# save as text file
data = np.transpose(np.vstack((t, v)))
with open (dat_file, "w") as f:
    np.savetxt(f, data)

# %%
import json
from os import listdir

nm_list = [486509232, 480624051, 482583564, 626170592, 473863510, 489932597, 626170718, 626170661, 477876583, 478809991, 560692892, 478513415, 480624414, 626170801, 626170430, 485611914, 626170421, 479694384, 549384713, 485720587, 626170610, 626170727, 477838913, 482520370, 471086533, 483108490, 489932435, 491517388, 556384271, 480630211, 486052435, 484620556, 329322394, 480631187, 477878554, 485467083, 484628276, 473871773, 472442377, 561405645, 476637723, 480613522, 480630344, 488763268, 480630395, 626170511, 491625600, 485513255, 489932551, 471081668, 478513461, 472430904, 626170583, 626170502, 480632564, 486556811, 626170475, 489932183, 480631048, 472455509, 482655070, 485591776, 485476031, 473835796, 489931686, 478513187, 485507735, 473871592, 476637699, 478513407, 488083972, 479234670, 482525598, 473863035, 480051220, 486557284, 486909496, 478810017, 485694403, 478045081, 482529696, 329321704, 487245719, 471087975, 472434498, 472912177, 473862845, 473834758, 552636652, 480631286, 479234441, 538907315, 478513445, 478513451, 488759006, 472450023, 478513443, 478045202, 473872986, 487245118, 480633088, 477876559, 480624126, 485513184, 472421285, 478513398, 477878284, 477880244, 476637796, 479234506, 488462820, 472352327, 626170646, 477839642, 478045226, 473862421, 480632594, 483156585, 482657528, 478513437, 483106906, 472363762, 487245869, 626170556, 556384280, 489932682, 626170619, 479427369, 626170574, 626170601, 472299294, 486508789, 473862496, 489932472, 477313251, 488462965, 486511108, 491623973, 472440759, 482934212, 480056382, 489931963, 486509958, 479695152, 626170736, 472451419, 471085845, 626170670, 478048947, 482524837, 488462783, 486052412, 479427516, 479427443, 485510685, 477510985, 478047618, 538907329, 478043748, 480630857, 472300877, 478513441, 626170484, 472447460, 476637747, 538906694, 478047737, 486556714, 472306460, 478513459, 485904766, 549384722, 472306616, 476679102, 473465774, 479694359, 480631402, 560692910, 477839613, 485909152, 486556597, 626170439, 483108201, 486508647, 485602029, 496930338, 626170529, 626170565, 472304676, 473465456, 626170679, 626170520, 626170547, 472912107, 554338972, 479694721, 482657381, 626170538, 626170637, 478809612, 477840124, 478513396, 478045347, 486558444, 476630516, 486144663, 486509010, 483066358, 480624251, 478513411, 543285979, 473863578, 487246046, 480633479, 478513224, 485510712, 485591806, 478047816, 626170628, 472306544, 486508702, 477510918, 480629276, 482525264, 485909125, 479234530, 488461970, 479694856, 480361288, 478047588, 485720616, 626170709, 486508758, 477494382, 483109057, 472299363]

list_dir = listdir('486509232')

filtered = filter(lambda x:x.endswith(".json"), list_dir)
print(filtered)
